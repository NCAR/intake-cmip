# %%
import os 
from dask.distributed import Client
from dask import delayed
import dask
from pathlib import Path
import re
import pandas as pd
from dask_jobqueue import SLURMCluster
PROJECT = os.environ["PBS_ACCOUNT"]

# %%
dask.config.set({'distributed.dashboard.link':'http://localhost:8877/proxy/{port}/status'})

# %%
cluster = SLURMCluster(project=PROJECT, processes=6, cores=12, memory="5GB",
                           env_extra=['export LANG="en_US.utf8"',
                                      'export LANGUAGE="en_US.utf8"',
                                      'export LC_ALL="en_US.utf8"',
                                      'export LD_LIBRARY_PATH=""',])

# %%
cluster
# Out:
# VBox(children=(HTML(value='<h2>SLURMCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    …

# %%
# !squeue -u $USER
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            1949765       dav     srun  abanihi  R      13:20      1 pronghorn01
#            1949785       dav dask-wor  abanihi  R       0:02      1 casper10
#            1949786       dav dask-wor  abanihi  R       0:02      1 casper10
#            1949787       dav dask-wor  abanihi  R       0:02      1 casper10
#            1949788       dav dask-wor  abanihi  R       0:02      1 casper10
#            1949789       dav dask-wor  abanihi  R       0:02      1 casper10
#            1949790       dav dask-wor  abanihi  R       0:02      1 casper11
#            1949791       dav dask-wor  abanihi  R       0:02      1 casper11
#            1949792       dav dask-wor  abanihi  R       0:02      1 casper11
#            1949793       dav dask-wor  abanihi  R       0:02      1 casper11
#            1949794       dav dask-wor  abanihi  R       0:02      1 casper11
#            1949795       dav dask-wor  abanihi  R       0:02      1 casper11
#            1949796       dav dask-wor  abanihi  R       0:02      1 casper12

# %%
client = Client(cluster)

# %%
client
# Out:
# <Client: scheduler='tcp://10.12.202.17:36607' processes=72 cores=144>

# %%
institutions = ['BCC', 'BNU', 'CCCma', 'CMCC', 'CNRM-CERFACS', 'CSIRO-BOM',
                'CSIRO-QCCCE', 'FIO', 'ICHEC', 'INM', 'INPE', 'IPSL',
                'LASG-CESS', 'LASG-IAP', 'MIROC', 'MOHC', 'MPI-M', 'MRI',
                'NASA-GISS', 'NCC', 'NIMR-KMA', 'NOAA-GFDL',
                'NSF-DOE-NCAR', 'UNSW', 'NCAR', ]
realms = ['atmos','land','landIce','ocean','ocnBgchem','seaIce']
frequencies = ['fx','day','mon','yr']
cmip5_root = "/glade/collections/cmip/cmip5"

# %%
modeling_groups = [os.path.join(cmip5_root, activity, institution) for institution in institutions for activity in
                   os.listdir(cmip5_root)
                   if os.path.isdir(os.path.join(cmip5_root, activity, institution))]

models = [os.path.join(modeling_group, model) for modeling_group in modeling_groups for model in os.listdir(modeling_group)]

# %%
modeling_groups[:2]
# Out:
# ['/glade/collections/cmip/cmip5/output1/BCC',
#  '/glade/collections/cmip/cmip5/output1/BNU']

# %%
models[:2]
# Out:
# ['/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1',
#  '/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1-m']

# %%
experiments = [os.path.join(model, exp) for model in models for exp in os.listdir(model)]

# %%
experiments[:2]
# Out:
# ['/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1/esmControl',
#  '/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1/historical']

# %%
freqs = [os.path.join(exp, freq) for exp in experiments for freq in os.listdir(exp)]
freqs[:2]
# Out:
# ['/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1/esmControl/mon',
#  '/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1/historical/6hr']

# %%
realm_dirs = [os.path.join(freq, realm) for freq in freqs for realm in os.listdir(freq)]
realm_dirs[0:2]
# Out:
# ['/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1/esmControl/mon/ocean',
#  '/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1/esmControl/mon/ocnBgchem']

# %%
len(modeling_groups), len(models), len(experiments), len(freqs), len(realm_dirs)
# Out:
# (38, 81, 418, 756, 1448)

# %%
def get_entry(directory):
    dir_split = directory.split('/')
    entry = {}
    entry['realm'] = dir_split[-1]
    entry['frequency'] = dir_split[-2]
    entry['experiment'] = dir_split[-3]
    entry['model'] = dir_split[-4]
    entry['institution'] = dir_split[-5]
    return entry

@delayed
def parse_files(directory):
    exclude = set(["files", "latests"]) # directories to exclude
    
    columns = ["ensemble", "experiment", "file_basename", "file_fullpath", 
                  "frequency", "institution", "model", "root", "realm", "varname"]
    df = pd.DataFrame(columns=columns)
    
    entry = get_entry(directory)
    
    for root, dirs, files in os.walk(directory):
        print(root)
        dirs[:] = [d for d in dirs if d not in exclude]
        if not files:
            continue
        sfiles = sorted([f for f in files if os.path.splitext(f)[1] == ".nc"])
        if not sfiles: continue
            
        fs = []
        for f in sfiles:
            try:
                f_split = f.split("_")
                entry['varname'] = f_split[0]
                entry['ensemble'] = f_split[-2]
                entry['root'] = root
                entry['file_basename'] = f
                entry['file_fullpath'] = os.path.join(root, f)
                fs.append(entry)
            except:
                continue
        if fs:
            temp_df = pd.DataFrame(fs)
                
        else:
            temp_df = pd.DataFrame()
            temp_df.columns = df.columns
        df = pd.concat([temp_df, df], ignore_index=True)
    return df

# %%
dfs = [parse_files(directory) for directory in realm_dirs]
len(dfs)
# Out:
# 1448

# %%
import dask.dataframe as dd

# %%
df = dd.from_delayed(dfs)

# %%
# %time df.head()
# Out:
# CPU times: user 55.6 ms, sys: 7.42 ms, total: 63.1 ms
# Wall time: 199 ms
#   ensemble  experiment                                      file_basename  \
# 0   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 1   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 2   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 3   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 4   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
#
#                                        file_fullpath frequency institution  \
# 0  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 1  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 2  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 3  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 4  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
#
#         model  realm                                               root  \
# 0  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 1  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 2  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 3  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 4  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
#
#   varname
# 0  thetao
# 1  thetao
# 2  thetao
# 3  thetao
# 4  thetao

# %%
# %time len(df)
# Out:
# CPU times: user 1min 16s, sys: 6.47 s, total: 1min 23s
# Wall time: 5min 36s
# 602260

# %%
# %time pdf = df.compute()
# Out:
# CPU times: user 1min 7s, sys: 5.66 s, total: 1min 12s
# Wall time: 4min 43s

# %%
pdf.head()
# Out:
#   ensemble  experiment                                      file_basename  \
# 0   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 1   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 2   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 3   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 4   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
#
#                                        file_fullpath frequency institution  \
# 0  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 1  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 2  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 3  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 4  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
#
#         model  realm                                               root  \
# 0  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 1  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 2  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 3  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 4  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
#
#   varname
# 0  thetao
# 1  thetao
# 2  thetao
# 3  thetao
# 4  thetao

# %%
pdf.model.nunique()
# Out:
# 55

# %%
pdf.realm.unique()
# Out:
# array(['ocean', 'ocnBgchem', 'atmos', 'land', 'seaIce', 'landIce',
#        'aerosol'], dtype=object)

# %%
pdf.varname.nunique()
# Out:
# 454

# %%
import re

# %%
vYYYYMMDD = r'v\d{4}\d{2}\d{2}'
vN = r'v\d{1}'
v = re.compile( "|".join([vYYYYMMDD, vN])) # Combine both regex into one

# %%
pdf["version"] = pdf.root.str.findall(v)

# %%
pdf.head()
# Out:
#   ensemble  experiment                                      file_basename  \
# 0   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 1   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 2   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 3   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
# 4   r1i1p1  esmControl  thetao_Omon_bcc-csm1-1_esmControl_r1i1p1_02410...
#
#                                        file_fullpath frequency institution  \
# 0  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 1  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 2  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 3  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
# 4  /glade/collections/cmip/cmip5/output1/BCC/bcc-...       mon         BCC
#
#         model  realm                                               root  \
# 0  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 1  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 2  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 3  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
# 4  bcc-csm1-1  ocean  /glade/collections/cmip/cmip5/output1/BCC/bcc-...
#
#   varname      version
# 0  thetao  [v20120202]
# 1  thetao  [v20120202]
# 2  thetao  [v20120202]
# 3  thetao  [v20120202]
# 4  thetao  [v20120202]

# %%
pdf.root[~pdf.root.str.contains(v)].iloc[0]
# Out:
# '/glade/collections/cmip/cmip5/output1/CCCma/CanESM2/historical/mon/atmos/Amon/r4i1p1'

# %%
pdf.root[pdf.root.str.contains(v)].iloc[0]
# Out:
# '/glade/collections/cmip/cmip5/output1/BCC/bcc-csm1-1/esmControl/mon/ocean/Omon/r1i1p1/v20120202/thetao'

# %%
pdf.version = pdf.version.apply(lambda x: x[0] if x else 'v0')
pdf.tail()
# Out:
#     ensemble experiment                                     file_basename  \
# 530   r1i1p1      rcp85  rhopoto_Omon_CCSM4_rcp85_r1i1p1_209001-210012.nc
# 531   r1i1p1      rcp85  rhopoto_Omon_CCSM4_rcp85_r1i1p1_209001-210012.nc
# 532   r1i1p1      rcp85  rhopoto_Omon_CCSM4_rcp85_r1i1p1_209001-210012.nc
# 533   r1i1p1      rcp85  rhopoto_Omon_CCSM4_rcp85_r1i1p1_209001-210012.nc
# 534   r1i1p1      rcp85  rhopoto_Omon_CCSM4_rcp85_r1i1p1_209001-210012.nc
#
#                                          file_fullpath frequency institution  \
# 530  /glade/collections/cmip/cmip5/output2/NCAR/CCS...       mon        NCAR
# 531  /glade/collections/cmip/cmip5/output2/NCAR/CCS...       mon        NCAR
# 532  /glade/collections/cmip/cmip5/output2/NCAR/CCS...       mon        NCAR
# 533  /glade/collections/cmip/cmip5/output2/NCAR/CCS...       mon        NCAR
# 534  /glade/collections/cmip/cmip5/output2/NCAR/CCS...       mon        NCAR
#
#      model  realm                                               root  varname  \
# 530  CCSM4  ocean  /glade/collections/cmip/cmip5/output2/NCAR/CCS...  rhopoto
# 531  CCSM4  ocean  /glade/collections/cmip/cmip5/output2/NCAR/CCS...  rhopoto
# 532  CCSM4  ocean  /glade/collections/cmip/cmip5/output2/NCAR/CCS...  rhopoto
# 533  CCSM4  ocean  /glade/collections/cmip/cmip5/output2/NCAR/CCS...  rhopoto
# 534  CCSM4  ocean  /glade/collections/cmip/cmip5/output2/NCAR/CCS...  rhopoto
#
#        version
# 530  v20120205
# 531  v20120205
# 532  v20120205
# 533  v20120205
# 534  v20120205

# %%
# %time len(pdf)
# Out:
# CPU times: user 17 µs, sys: 1 µs, total: 18 µs
# Wall time: 27.7 µs
# 602260

# %%
sorted_df = pdf.sort_values('version').drop_duplicates(subset='file_basename', keep='last')

# %%
# %time len(sorted_df)
# Out:
# CPU times: user 19 µs, sys: 2 µs, total: 21 µs
# Wall time: 30.5 µs
# 87565

# %%
sorted_df.to_csv("/glade/u/home/abanihi/sorted_cmip5_database.csv", index=False)
pdf.to_csv("/glade/u/home/abanihi/unsorted_cmip5_database.csv", index=False)

# %%
sorted_df.groupby('model').nunique()
# Out:
#                 ensemble  experiment  file_basename  file_fullpath  frequency  \
# model
# ACCESS1-0              3           3            190            190          4
# ACCESS1-3              3           6            213            213          4
# ACCESS1.0              2           3              3              3          1
# BNU-ESM                1           6             75             75          4
# CCSM4                 87          44          55336          55336          5
# CESM1-BGC             15          12           3804           3804          4
# CESM1-CAM5            37          16           7075           7075          5
# CESM1-FASTCHEM         5           2            633            633          3
# CESM1-WACCM           12           5           3214           3214          3
# CMCC-CESM              1           2             75             75          2
# CMCC-CM                1           4             50             50          4
# CMCC-CMS               1           4             45             45          2
# CNRM-CM5              10           4            291            291          4
# CNRM-CM5-2             1           1             15             15          1
# CSIRO-Mk3-6-0         42           8           1233           1233          3
# CSIRO-Mk3L-1-2         3           2             48             48          1
# CanCM4                10           2            150            150          1
# CanESM2               17          11            839            839          3
# EC-EARTH              13           3            343            343          3
# FGOALS-g2              5           6            135            135          4
# FGOALS-s2              3           2             36             36          1
# FIO-ESM                3           6             73             73          1
# GFDL-CM2p1            10           1             40             40          1
# GFDL-CM3               5           4            457            457          4
# GFDL-ESM2G             3           8            547            547          5
# GFDL-ESM2M             8           9            624            624          5
# GISS-E2-H            113           8           1762           1762          4
# GISS-E2-H-CC           1           3             73             73          1
# GISS-E2-R            137           8           1939           1939          4
# GISS-E2-R-CC           1           3             73             73          1
# HadCM3                10           2            404            404          2
# HadGEM2-A              1           1              5              5          1
# HadGEM2-AO             1           3             48             48          2
# HadGEM2-CC             3           3            456            456          3
# HadGEM2-ES             5           6           1144           1144          5
# IPSL-CM5A-LR          20           8           1410           1410          5
# IPSL-CM5A-MR           6           4            339            339          4
# IPSL-CM5B-LR           1           3            140            140          3
# MIROC-ESM              3           8            349            349          5
# MIROC-ESM-CHEM         9           5            200            200          4
# MIROC4h                3           2            205            205          2
# MIROC5                 5           5            839            839          4
# MPI-ESM-LR             3           9            905            905          4
# MPI-ESM-MR             3           4            253            253          3
# MPI-ESM-P              2           1             32             32          2
# MRI-AGCM3-2H           1           1              5              5          1
# MRI-AGCM3-2S           1           1              3              3          1
# MRI-CGCM3              5           4            407            407          4
# MRI-ESM1               1           5            237            237          4
# NorESM1-M              3           4            264            264          4
# NorESM1-ME             2           8            262            262          2
# bcc-csm1-1             3           9             71             71          3
# bcc-csm1-1-m           3           9             74             74          3
# fio-esm                3           6             47             47          1
# inmcm4                 1           6             75             75          5
#
#                 institution  model  realm   root  varname  version
# model
# ACCESS1-0                 1      1      4    190       59       11
# ACCESS1-3                 1      1      3    213       53       17
# ACCESS1.0                 1      1      1      3        1        1
# BNU-ESM                   1      1      6     75       41        3
# CCSM4                     1      1      5  55336      190       95
# CESM1-BGC                 1      1      6   3804      219       22
# CESM1-CAM5                1      1      6   7075      181       52
# CESM1-FASTCHEM            1      1      5    633      152        6
# CESM1-WACCM               1      1      5   3214      156       19
# CMCC-CESM                 1      1      5     75       46        6
# CMCC-CM                   1      1      4     50       19        7
# CMCC-CMS                  1      1      4     45       16        2
# CNRM-CM5                  1      1      5    291       56       12
# CNRM-CM5-2                1      1      2     15       15        1
# CSIRO-Mk3-6-0             1      1      4   1233       58        4
# CSIRO-Mk3L-1-2            1      1      2     48        9        2
# CanCM4                    1      1      2    150       10        1
# CanESM2                   1      1      7    839      113       10
# EC-EARTH                  1      1      2    343       18       33
# FGOALS-g2                 1      1      4    135       31        5
# FGOALS-s2                 1      1      2     36       11        2
# FIO-ESM                   1      1      5     73       39        4
# GFDL-CM2p1                1      1      2     40        4        1
# GFDL-CM3                  1      1      3    457       90        3
# GFDL-ESM2G                1      1      5    547      190        6
# GFDL-ESM2M                1      1      5    624      255        6
# GISS-E2-H                 1      1      4   1762       74       20
# GISS-E2-H-CC              1      1      4     73       55        3
# GISS-E2-R                 1      1      4   1939       75       33
# GISS-E2-R-CC              1      1      4     73       55        4
# HadCM3                    1      1      3    404       23        4
# HadGEM2-A                 1      1      1      5        5        1
# HadGEM2-AO                1      1      2     48       15        2
# HadGEM2-CC                1      1      3    456       71       19
# HadGEM2-ES                2      1      5   1144      194       30
# IPSL-CM5A-LR              1      1      5   1410      153       14
# IPSL-CM5A-MR              1      1      4    339       89        5
# IPSL-CM5B-LR              1      1      4    140       87        3
# MIROC-ESM                 1      1      7    349      107        8
# MIROC-ESM-CHEM            1      1      6    200       71        7
# MIROC4h                   1      1      4    205       56        4
# MIROC5                    1      1      5    839       72       15
# MPI-ESM-LR                1      1      6    905      161        7
# MPI-ESM-MR                1      1      5    253       77        2
# MPI-ESM-P                 1      1      3     32       14        1
# MRI-AGCM3-2H              1      1      1      5        5        1
# MRI-AGCM3-2S              1      1      1      3        3        1
# MRI-CGCM3                 1      1      5    407       70        8
# MRI-ESM1                  1      1      7    237      134        5
# NorESM1-M                 1      1      4    264       65        5
# NorESM1-ME                1      1      6    262      126        4
# bcc-csm1-1                1      1      6     71       36        4
# bcc-csm1-1-m              1      1      6     74       36        6
# fio-esm                   1      1      4     47       17        4
# inmcm4                    1      1      5     75       43        2
