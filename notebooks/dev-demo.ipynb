# %% [markdown]
# # Intake Plugin for CMIP5

# %% [markdown]
# The directory `intake-cmip5` contains a full package to do the job

# %%
# !find ../intake_cmip5/
# Out:
# ../intake_cmip5/
# ../intake_cmip5//generate_database.py
# ../intake_cmip5//_version.py
# ../intake_cmip5//__init__.py
# ../intake_cmip5//__pycache__
# ../intake_cmip5//__pycache__/_version.cpython-36.pyc
# ../intake_cmip5//__pycache__/generate_database.cpython-36.pyc
# ../intake_cmip5//__pycache__/source.cpython-36.pyc
# ../intake_cmip5//__pycache__/__init__.cpython-36.pyc
# ../intake_cmip5//source.py

# %% [markdown]
# `intake-cmip5` contains just one DataSource class, although it could have several related source.
# The [source code](https://github.com/NCAR/intake-cmip5) has `CMIP5DataSource` class which subclasses `intake_xarray.base.DataSourceMixin` class. `CMIP5DataSource` has the following class-level attributes:
#
# ```python
#
# class CMIP5DataSource(intake_xarray.base.DataSourceMixin):
#     container = 'xarray'
#     version = '0.0.1'
#     partition_access = True
#     name = 'cmip5'
# ```
#
# These attributes
#  - name the new plugin,
#  - give it a version and
#  - an output data type (xarray container),
#  - and specify that the data will always be loaded in partitions.

# %%
# Install the package
# !cd .. && python setup.py develop
# Out:
# running develop
# running egg_info
# writing intake_cmip5.egg-info/PKG-INFO
# writing dependency_links to intake_cmip5.egg-info/dependency_links.txt
# writing entry points to intake_cmip5.egg-info/entry_points.txt
# writing requirements to intake_cmip5.egg-info/requires.txt
# writing top-level names to intake_cmip5.egg-info/top_level.txt
# file intake_cmip5.py (for module intake_cmip5) not found
# reading manifest file 'intake_cmip5.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.yaml' under directory '.'
# writing manifest file 'intake_cmip5.egg-info/SOURCES.txt'
# running build_ext
# Creating /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/intake-cmip5.egg-link (link to .)
# intake-cmip5 0+untagged.46.g1490232.dirty is already the active version in easy-install.pth
#
# Installed /Users/abanihi/devel/ncar/intake-cmip5
# Processing dependencies for intake-cmip5==0+untagged.46.g1490232.dirty
# Searching for intake-xarray==0.2.4
# Best match: intake-xarray 0.2.4
# Adding intake-xarray 0.2.4 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for intake==0.2.9
# Best match: intake 0.2.9
# Adding intake 0.2.9 to easy-install.pth file
# Installing intake script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing intake-server script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for xarray==0.11.0
# Best match: xarray 0.11.0
# Adding xarray 0.11.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for pandas==0.23.4
# Best match: pandas 0.23.4
# Adding pandas 0.23.4 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for pytest==4.0.1
# Best match: pytest 4.0.1
# Adding pytest 4.0.1 to easy-install.pth file
# Installing py.test script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing pytest script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for requests==2.19.1
# Best match: requests 2.19.1
# Adding requests 2.19.1 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for dask==0.20.2
# Best match: dask 0.20.2
# Adding dask 0.20.2 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for scipy==1.1.0
# Best match: scipy 1.1.0
# Adding scipy 1.1.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for python-snappy==0.5.3
# Best match: python-snappy 0.5.3
# Adding python-snappy 0.5.3 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for msgpack-numpy==0.4.3.2
# Best match: msgpack-numpy 0.4.3.2
# Adding msgpack-numpy 0.4.3.2 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for ipywidgets==7.4.2
# Best match: ipywidgets 7.4.2
# Adding ipywidgets 7.4.2 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for Jinja2==2.10
# Best match: Jinja2 2.10
# Processing Jinja2-2.10-py3.6.egg
# Jinja2 2.10 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/Jinja2-2.10-py3.6.egg
# Searching for ruamel.yaml==0.15.77
# Best match: ruamel.yaml 0.15.77
# Adding ruamel.yaml 0.15.77 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for msgpack-python==0.5.6
# Best match: msgpack-python 0.5.6
# Processing msgpack_python-0.5.6-py3.6-macosx-10.9-x86_64.egg
# msgpack-python 0.5.6 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/msgpack_python-0.5.6-py3.6-macosx-10.9-x86_64.egg
# Searching for six==1.11.0
# Best match: six 1.11.0
# Adding six 1.11.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for appdirs==1.4.3
# Best match: appdirs 1.4.3
# Processing appdirs-1.4.3-py3.6.egg
# appdirs 1.4.3 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/appdirs-1.4.3-py3.6.egg
# Searching for holoviews==1.11.0a10
# Best match: holoviews 1.11.0a10
# Adding holoviews 1.11.0a10 to easy-install.pth file
# Installing holoviews script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for numpy==1.15.4
# Best match: numpy 1.15.4
# Adding numpy 1.15.4 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for tornado==5.1.1
# Best match: tornado 5.1.1
# Adding tornado 5.1.1 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for python-dateutil==2.7.3
# Best match: python-dateutil 2.7.3
# Processing python_dateutil-2.7.3-py3.6.egg
# python-dateutil 2.7.3 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/python_dateutil-2.7.3-py3.6.egg
# Searching for pytz==2018.5
# Best match: pytz 2018.5
# Processing pytz-2018.5-py3.6.egg
# pytz 2018.5 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/pytz-2018.5-py3.6.egg
# Searching for pluggy==0.7.1
# Best match: pluggy 0.7.1
# Adding pluggy 0.7.1 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for atomicwrites==1.2.1
# Best match: atomicwrites 1.2.1
# Processing atomicwrites-1.2.1-py3.6.egg
# atomicwrites 1.2.1 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/atomicwrites-1.2.1-py3.6.egg
# Searching for more-itertools==4.3.0
# Best match: more-itertools 4.3.0
# Adding more-itertools 4.3.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for attrs==18.2.0
# Best match: attrs 18.2.0
# Processing attrs-18.2.0-py3.6.egg
# attrs 18.2.0 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/attrs-18.2.0-py3.6.egg
# Searching for setuptools==40.4.3
# Best match: setuptools 40.4.3
# Adding setuptools 40.4.3 to easy-install.pth file
# Installing easy_install script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for py==1.7.0
# Best match: py 1.7.0
# Adding py 1.7.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for certifi==2018.10.15
# Best match: certifi 2018.10.15
# Adding certifi 2018.10.15 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for urllib3==1.23
# Best match: urllib3 1.23
# Adding urllib3 1.23 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for idna==2.7
# Best match: idna 2.7
# Adding idna 2.7 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for msgpack==0.5.6
# Best match: msgpack 0.5.6
# Adding msgpack 0.5.6 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for ipykernel==5.0.0
# Best match: ipykernel 5.0.0
# Adding ipykernel 5.0.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for nbformat==4.4.0
# Best match: nbformat 4.4.0
# Adding nbformat 4.4.0 to easy-install.pth file
# Installing jupyter-trust script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for widgetsnbextension==3.4.2
# Best match: widgetsnbextension 3.4.2
# Adding widgetsnbextension 3.4.2 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for traitlets==4.3.2
# Best match: traitlets 4.3.2
# Adding traitlets 4.3.2 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for ipython==7.0.1
# Best match: ipython 7.0.1
# Adding ipython 7.0.1 to easy-install.pth file
# Installing iptest script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing iptest3 script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing ipython script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing ipython3 script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for MarkupSafe==1.0
# Best match: MarkupSafe 1.0
# Adding MarkupSafe 1.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for cloudpickle==0.5.6
# Best match: cloudpickle 0.5.6
# Adding cloudpickle 0.5.6 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for distributed==1.24.2
# Best match: distributed 1.24.2
# Adding distributed 1.24.2 to easy-install.pth file
# Installing dask-ssh script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing dask-submit script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing dask-remote script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing dask-scheduler script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing dask-worker script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing dask-mpi script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for partd==0.3.9
# Best match: partd 0.3.9
# Processing partd-0.3.9-py3.6.egg
# partd 0.3.9 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/partd-0.3.9-py3.6.egg
# Searching for toolz==0.9.0
# Best match: toolz 0.9.0
# Processing toolz-0.9.0-py3.6.egg
# toolz 0.9.0 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/toolz-0.9.0-py3.6.egg
# Searching for pyviz-comms==0.6.0
# Best match: pyviz-comms 0.6.0
# Adding pyviz-comms 0.6.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for param==1.7.0
# Best match: param 1.7.0
# Adding param 1.7.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for jupyter-client==5.2.4
# Best match: jupyter-client 5.2.4
# Processing jupyter_client-5.2.4-py3.6.egg
# jupyter-client 5.2.4 is already the active version in easy-install.pth
# Installing jupyter-kernel script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing jupyter-kernelspec script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing jupyter-run script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/jupyter_client-5.2.4-py3.6.egg
# Searching for jupyter-core==4.4.0
# Best match: jupyter-core 4.4.0
# Adding jupyter-core 4.4.0 to easy-install.pth file
# Installing jupyter script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing jupyter-migrate script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing jupyter-troubleshoot script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for jsonschema==2.6.0
# Best match: jsonschema 2.6.0
# Adding jsonschema 2.6.0 to easy-install.pth file
# Installing jsonschema script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for ipython-genutils==0.2.0
# Best match: ipython-genutils 0.2.0
# Processing ipython_genutils-0.2.0-py3.6.egg
# ipython-genutils 0.2.0 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/ipython_genutils-0.2.0-py3.6.egg
# Searching for notebook==5.7.0
# Best match: notebook 5.7.0
# Adding notebook 5.7.0 to easy-install.pth file
# Installing jupyter-bundlerextension script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing jupyter-nbextension script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing jupyter-notebook script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
# Installing jupyter-serverextension script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for decorator==4.3.0
# Best match: decorator 4.3.0
# Adding decorator 4.3.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for appnope==0.1.0
# Best match: appnope 0.1.0
# Adding appnope 0.1.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for pexpect==4.6.0
# Best match: pexpect 4.6.0
# Adding pexpect 4.6.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for backcall==0.1.0
# Best match: backcall 0.1.0
# Adding backcall 0.1.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for Pygments==2.3.1
# Best match: Pygments 2.3.1
# Processing Pygments-2.3.1-py3.6.egg
# Pygments 2.3.1 is already the active version in easy-install.pth
# Installing pygmentize script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/Pygments-2.3.1-py3.6.egg
# Searching for prompt-toolkit==2.0.5
# Best match: prompt-toolkit 2.0.5
# Adding prompt-toolkit 2.0.5 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for simplegeneric==0.8.1
# Best match: simplegeneric 0.8.1
# Processing simplegeneric-0.8.1-py3.6.egg
# simplegeneric 0.8.1 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/simplegeneric-0.8.1-py3.6.egg
# Searching for pickleshare==0.7.5
# Best match: pickleshare 0.7.5
# Adding pickleshare 0.7.5 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for jedi==0.13.1
# Best match: jedi 0.13.1
# Adding jedi 0.13.1 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for PyYAML==3.13
# Best match: PyYAML 3.13
# Adding PyYAML 3.13 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for zict==0.1.3
# Best match: zict 0.1.3
# Adding zict 0.1.3 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for tblib==1.3.2
# Best match: tblib 1.3.2
# Processing tblib-1.3.2-py3.6.egg
# tblib 1.3.2 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/tblib-1.3.2-py3.6.egg
# Searching for sortedcontainers==2.0.5
# Best match: sortedcontainers 2.0.5
# Adding sortedcontainers 2.0.5 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for psutil==5.4.7
# Best match: psutil 5.4.7
# Adding psutil 5.4.7 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for Click==7.0
# Best match: Click 7.0
# Processing Click-7.0-py3.6.egg
# Click 7.0 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/Click-7.0-py3.6.egg
# Searching for locket==0.2.0
# Best match: locket 0.2.0
# Processing locket-0.2.0-py3.6.egg
# locket 0.2.0 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/locket-0.2.0-py3.6.egg
# Searching for pyzmq==17.0.0
# Best match: pyzmq 17.0.0
# Adding pyzmq 17.0.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for prometheus-client==0.5.0
# Best match: prometheus-client 0.5.0
# Processing prometheus_client-0.5.0-py3.6.egg
# prometheus-client 0.5.0 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/prometheus_client-0.5.0-py3.6.egg
# Searching for terminado==0.8.1
# Best match: terminado 0.8.1
# Adding terminado 0.8.1 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for Send2Trash==1.5.0
# Best match: Send2Trash 1.5.0
# Adding Send2Trash 1.5.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for nbconvert==5.3.1
# Best match: nbconvert 5.3.1
# Adding nbconvert 5.3.1 to easy-install.pth file
# Installing jupyter-nbconvert script to /Users/abanihi/opt/miniconda3/envs/pangeo/bin
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for ptyprocess==0.6.0
# Best match: ptyprocess 0.6.0
# Adding ptyprocess 0.6.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for wcwidth==0.1.7
# Best match: wcwidth 0.1.7
# Processing wcwidth-0.1.7-py3.6.egg
# wcwidth 0.1.7 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/wcwidth-0.1.7-py3.6.egg
# Searching for parso==0.3.1
# Best match: parso 0.3.1
# Adding parso 0.3.1 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for heapdict==1.0.0
# Best match: heapdict 1.0.0
# Adding heapdict 1.0.0 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for testpath==0.3.1
# Best match: testpath 0.3.1
# Adding testpath 0.3.1 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for pandocfilters==1.4.2
# Best match: pandocfilters 1.4.2
# Processing pandocfilters-1.4.2-py3.6.egg
# pandocfilters 1.4.2 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/pandocfilters-1.4.2-py3.6.egg
# Searching for bleach==3.0.2
# Best match: bleach 3.0.2
# Processing bleach-3.0.2-py3.6.egg
# bleach 3.0.2 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/bleach-3.0.2-py3.6.egg
# Searching for mistune==0.8.3
# Best match: mistune 0.8.3
# Adding mistune 0.8.3 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for entrypoints==0.2.3
# Best match: entrypoints 0.2.3
# Adding entrypoints 0.2.3 to easy-install.pth file
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages
# Searching for webencodings==0.5.1
# Best match: webencodings 0.5.1
# Processing webencodings-0.5.1-py3.6.egg
# webencodings 0.5.1 is already the active version in easy-install.pth
#
# Using /Users/abanihi/opt/miniconda3/envs/pangeo/lib/python3.6/site-packages/webencodings-0.5.1-py3.6.egg
# Finished processing dependencies for intake-cmip5==0+untagged.46.g1490232.dirty

# %% [markdown]
# Since the class is in the top-level of the package i.e `__init__.py`, and the package name starts with intake_, it will be scanned when Intake is imported. Now the plugin automatically appears in the set of known plugins in the Intake registry, and an associated `intake.open_cmip5` function is created at import time.

# %%
import intake

# %%
'cmip5' in intake.registry
# Out:
# True

# %% [markdown]
# ## Generate fake cmip5 data + cmip5 database
#
# For `intake-cmip5` to generate catalogs, we need to generate a database. To generate this database, we use [CMIP5 Data Reference Syntax](https://cmip.llnl.gov/cmip5/docs/cmip5_data_reference_syntax_v1-00_clean.pdf) to infer directory structure. Using `os.walk()`, we generate necessary information for each file. This database is then persisted to disk as an `csv` file. This file has the following columns:
# - ensemble
# - experiment
# - file_basename
# - file_fullpath
# - frequency
# - realm
# - institution
# - model
# - varname

# %%
import os
import pandas as pd
import xarray as xr
import shutil
import tempfile
from intake_cmip5.generate_database import create_CMIP5Database

# %%
CMIP5_TEST_DIR = tempfile.mkdtemp()
DB_DIR = tempfile.mkdtemp()
file_names = [
    "Tair_Amon_CanESM2_rcp85_r2i1p1_200601-203512.nc",
    "Tair_OImon_CSIRO-Mk3-6-0_historical_r2i1p1_200601-203512.nc",
]

# %%
def setup():
    test_paths = [
        f"{CMIP5_TEST_DIR}/output1/CCCma/CanESM2/rcp85/mon/atmos/Amon/r2i1p1",
        f"{CMIP5_TEST_DIR}/output2/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/seaIce/OImon/r2i1p1/v1/sic",
    ]

    ds = (
        xr.tutorial.open_dataset("rasm")
        .load()
        .isel(time=slice(0, 2), x=slice(0, 5), y=slice(0, 3))
    )

    for idx, path in enumerate(test_paths):
        os.makedirs(path, exist_ok=True)
        file_path = f"{path}/{file_names[idx]}"
        ds.to_netcdf(file_path, mode="w")

# %%
# Generate fake cmip5 database
setup()
create_CMIP5Database(CMIP5_TEST_DIR, DB_DIR)
# Out:
# **** Persisting CMIP5 database in /var/folders/z7/sdhzbbr96bv2wjrsb92qsm3dwz5p3x/T/tmpkwyvtz9y ****
#   ensemble  experiment                                      file_basename  \
# 0   r2i1p1  historical  Tair_OImon_CSIRO-Mk3-6-0_historical_r2i1p1_200...
# 1   r2i1p1       rcp85    Tair_Amon_CanESM2_rcp85_r2i1p1_200601-203512.nc
#
#                                        file_fullpath frequency  institution  \
# 0  /var/folders/z7/sdhzbbr96bv2wjrsb92qsm3dwz5p3x...       mon  CSIRO-QCCCE
# 1  /var/folders/z7/sdhzbbr96bv2wjrsb92qsm3dwz5p3x...       mon        CCCma
#
#            model   realm                                               root  \
# 0  CSIRO-Mk3-6-0  seaIce  /var/folders/z7/sdhzbbr96bv2wjrsb92qsm3dwz5p3x...
# 1        CanESM2   atmos  /var/folders/z7/sdhzbbr96bv2wjrsb92qsm3dwz5p3x...
#
#   varname version
# 0    Tair      v2
# 1    Tair      v2

# %%
# !ls /var/folders/z7/sdhzbbr96bv2wjrsb92qsm3dwz5p3x/T/tmp5o57dy80
# Out:
# clean_cmip5_database.csv raw_cmip5_database.csv

# %% [markdown]
# ## Use `intake-cmip5` Plugin

# %%
db_file_path = f"{DB_DIR}/clean_cmip5_database.csv"

# %%
source = intake.open_cmip5(database_file=db_file_path, model="CanESM2", experiment="rcp85",
                           frequency="mon", realm="atmos", ensemble="r2i1p1",
                           varname="Tair")

# %%
source

# %%
source.discover()
# Out:
# {'datashape': None,
#  'dtype': None,
#  'shape': None,
#  'npartitions': None,
#  'metadata': {'dims': {'ensemble': 1, 'time': 2, 'x': 5, 'y': 3},
#   'data_vars': {'Tair': ['time', 'xc', 'yc', 'ensemble']},
#   'coords': ('time', 'xc', 'yc', 'ensemble'),
#   'title': '/workspace/jhamman/processed/R1002RBRxaaa01a/lnd/temp/R1002RBRxaaa01a.vic.ha.1979-09-01.nc',
#   'institution': 'U.W.',
#   'source': 'RACM R1002RBRxaaa01a',
#   'output_frequency': 'daily',
#   'output_mode': 'averaged',
#   'convention': 'CF-1.4',
#   'references': 'Based on the initial model of Liang et al., 1994, JGR, 99, 14,415- 14,429.',
#   'comment': 'Output from the Variable Infiltration Capacity (VIC) model.',
#   'nco_openmp_thread_number': 1,
#   'NCO': '"4.6.0"',
#   'history': 'Tue Dec 27 14:15:22 2016: ncatted -a dimensions,,d,, rasm.nc rasm.nc\nTue Dec 27 13:38:40 2016: ncks -3 rasm.nc rasm.nc\nhistory deleted for brevity'}}

# %%
out = source.to_dask()

# %%
out
# Out:
# <xarray.Dataset>
# Dimensions:   (ensemble: 1, time: 2, x: 5, y: 3)
# Coordinates:
#   * time      (time) object 1980-09-16 12:00:00 1980-10-17 00:00:00
#     xc        (y, x) float64 189.2 189.4 189.6 189.7 ... 188.9 189.0 189.2 189.4
#     yc        (y, x) float64 16.53 16.78 17.02 17.27 ... 17.1 17.34 17.59 17.84
#   * ensemble  (ensemble) <U6 'r2i1p1'
# Dimensions without coordinates: x, y
# Data variables:
#     Tair      (ensemble, time, y, x) float64 dask.array<shape=(1, 2, 3, 5), chunksize=(1, 2, 3, 5)>
# Attributes:
#     title:                     /workspace/jhamman/processed/R1002RBRxaaa01a/l...
#     institution:               U.W.
#     source:                    RACM R1002RBRxaaa01a
#     output_frequency:          daily
#     output_mode:               averaged
#     convention:                CF-1.4
#     references:                Based on the initial model of Liang et al., 19...
#     comment:                   Output from the Variable Infiltration Capacity...
#     nco_openmp_thread_number:  1
#     NCO:                       "4.6.0"
#     history:                   Tue Dec 27 14:15:22 2016: ncatted -a dimension...

# %%
print(source.yaml(True))
# Out:
# plugins:
#   source:
#   - module: intake_cmip5.source
# sources:
#   cmip5:
#     args:
#       database_file: /var/folders/z7/sdhzbbr96bv2wjrsb92qsm3dwz5p3x/T/tmpkwyvtz9y/clean_cmip5_database.csv
#       ensemble: r2i1p1
#       experiment: rcp85
#       frequency: mon
#       model: CanESM2
#       realm: atmos
#       varname: Tair
#     description: ''
#     driver: cmip5
#     metadata:
#       NCO: '"4.6.0"'
#       comment: Output from the Variable Infiltration Capacity (VIC) model.
#       convention: CF-1.4
#       coords: !!python/tuple
#       - time
#       - xc
#       - yc
#       - ensemble
#       data_vars:
#         Tair:
#         - time
#         - xc
#         - yc
#         - ensemble
#       dims:
#         ensemble: 1
#         time: 2
#         x: 5
#         y: 3
#       history: "Tue Dec 27 14:15:22 2016: ncatted -a dimensions,,d,, rasm.nc rasm.nc\n\
#         Tue Dec 27 13:38:40 2016: ncks -3 rasm.nc rasm.nc\nhistory deleted for brevity"
#       institution: U.W.
#       nco_openmp_thread_number: !!python/object/apply:numpy.core.multiarray.scalar
#       - !!python/object/apply:numpy.dtype
#         args:
#         - i4
#         - 0
#         - 1
#         state: !!python/tuple
#         - 3
#         - <
#         - null
#         - null
#         - null
#         - -1
#         - -1
#         - 0
#       - !!binary |
#         AQAAAA==
#       output_frequency: daily
#       output_mode: averaged
#       references: Based on the initial model of Liang et al., 1994, JGR, 99, 14,415-
#         14,429.
#       source: RACM R1002RBRxaaa01a
#       title: /workspace/jhamman/processed/R1002RBRxaaa01a/lnd/temp/R1002RBRxaaa01a.vic.ha.1979-09-01.nc
